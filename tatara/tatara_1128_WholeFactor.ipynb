# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series,DataFrame

# 可視化モジュール
import matplotlib.pyplot as plt
import matplotlib as mpl
#import seaborn as sns
# %matplotlib inline

# 小数第３まで表示
# %precision 3
# Out:
# '%.3f'

# %%
Collision_data = pd.read_csv('NYC_accidents_heat_map.csv')
Collision_data.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  10/22/2017  0:00      BRONX    10453  40.861862 -73.912820
# 1  10/22/2017  0:00   BROOKLYN    11211  40.714073 -73.950615
# 2  10/22/2017  0:00  MANHATTAN    10011  40.739136 -73.999260
# 3  10/22/2017  0:00  MANHATTAN    10025  40.794235 -73.962814
# 4  10/22/2017  0:00     QUEENS    11428  40.720375 -73.732260
#
#                   LOCATION                    ON STREET NAME  \
# 0   (40.861862, -73.91282)  WEST FORDHAM ROAD
# 1  (40.714073, -73.950615)                               NaN
# 2   (40.739136, -73.99926)                               NaN
# 3  (40.794235, -73.962814)  CENTRAL PARK WEST
# ...

# %%
Collision_data['la'] = Collision_data['LATITUDE'].map(lambda x : round(float(x),3))
Collision_data['lo'] = Collision_data['LONGITUDE'].map(lambda x : round(float(x),3))

# %%
Dummy = pd.get_dummies(Collision_data['CONTRIBUTING FACTOR VEHICLE 1'])
Dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1139133 entries, 0 to 1139132
# Data columns (total 48 columns):
# Accelerator Defective                                    1139133 non-null uint8
# Aggressive Driving/Road Rage                             1139133 non-null uint8
# Alcohol Involvement                                      1139133 non-null uint8
# Animals Action                                           1139133 non-null uint8
# Backing Unsafely                                         1139133 non-null uint8
# Brakes Defective                                         1139133 non-null uint8
# Cell Phone (hand-held)                                   1139133 non-null uint8
# Cell Phone (hands-free)                                  1139133 non-null uint8
# Driver Inattention/Distraction                           1139133 non-null uint8
# Driver Inexperience                                      1139133 non-null uint8
# ...

# %%
df = pd.DataFrame(Dummy.sum())
df.head()
# Out:
#                                   0
# Accelerator Defective           495
# Aggressive Driving/Road Rage   3674
# Alcohol Involvement            9400
# Animals Action                  628
# Backing Unsafely              35278

# %%
bus_list = df.loc[['Backing Unsafely', 'Driver Inattention/Distraction',
       'Driver Inexperience', 'Failure to Yield Right-of-Way',
       'Fatigued/Drowsy', 'Lost Consciousness', 'Other Vehicular',
       'Outside Car Distraction', 'Oversized Vehicle', 'Pavement Slippery',
       'Prescription Medication', 'Turning Improperly'],:]
bus_list
# Out:
#                                      0
# Backing Unsafely                 35278
# Driver Inattention/Distraction  163270
# Driver Inexperience              14730
# Failure to Yield Right-of-Way    53023
# Fatigued/Drowsy                  48443
# Lost Consciousness               20220
# Other Vehicular                  34480
# Outside Car Distraction          10846
# Oversized Vehicle                 6731
# Pavement Slippery                11125
# Prescription Medication          15900
# Turning Improperly               27894

# %%
bus_list.to_csv('bus_list_num.csv')

# %%
bus_list.sum()
# Out:
# 0    441940
# dtype: int64

# %%
i=0
for i in range(len(bus_list.index)):
    bus_list.iloc[i,0] = bus_list.iloc[i,0]/441940
bus_list
# Out:
#                                        0
# Backing Unsafely                0.079825
# Driver Inattention/Distraction  0.369439
# Driver Inexperience             0.033330
# Failure to Yield Right-of-Way   0.119978
# Fatigued/Drowsy                 0.109614
# Lost Consciousness              0.045753
# Other Vehicular                 0.078020
# Outside Car Distraction         0.024542
# Oversized Vehicle               0.015231
# Pavement Slippery               0.025173
# Prescription Medication         0.035978
# Turning Improperly              0.063117

# %%
taxi_list = df.loc[['Aggressive Driving/Road Rage', 'Alcohol Involvement',
       'Backing Unsafely', 'Brakes Defective',
       'Driver Inattention/Distraction', 'Driver Inexperience',
       'Failure to Yield Right-of-Way', 'Fatigued/Drowsy',
       'Following Too Closely', 'Illness', 'Lost Consciousness',
       'Other Electronic Device', 'Other Vehicular', 'Outside Car Distraction',
       'Oversized Vehicle', 'Passenger Distraction',
       'Passing or Lane Usage Improper', 'Pavement Slippery',
       'Physical Disability', 'Prescription Medication',
       'Reaction to Other Uninvolved Vehicle', 'Traffic Control Disregarded',
       'Turning Improperly', 'Unsafe Lane Changing', 'Unsafe Speed',
       'View Obstructed/Limited'],:]
taxi_list
# Out:
#                                            0
# Aggressive Driving/Road Rage            3674
# Alcohol Involvement                     9400
# Backing Unsafely                       35278
# Brakes Defective                        2988
# Driver Inattention/Distraction        163270
# Driver Inexperience                    14730
# Failure to Yield Right-of-Way          53023
# Fatigued/Drowsy                        48443
# Following Too Closely                  25972
# Illness                                 2535
# Lost Consciousness                     20220
# Other Electronic Device                 2260
# Other Vehicular                        34480
# Outside Car Distraction                10846
# Oversized Vehicle                       6731
# Passenger Distraction                   5028
# Passing or Lane Usage Improper         12167
# Pavement Slippery                      11125
# Physical Disability                     9362
# Prescription Medication                15900
# ...

# %%
taxi_list.to_csv('taxi_list_num.csv')

# %%
taxi_list.sum()
# Out:
# 0    556246
# dtype: int64

# %%
i=0
for i in range(len(taxi_list.index)):
    taxi_list.iloc[i,0] = taxi_list.iloc[i,0]/556246
taxi_list
# Out:
#                                              0
# Aggressive Driving/Road Rage          0.006605
# Alcohol Involvement                   0.016899
# Backing Unsafely                      0.063422
# Brakes Defective                      0.005372
# Driver Inattention/Distraction        0.293521
# Driver Inexperience                   0.026481
# Failure to Yield Right-of-Way         0.095323
# Fatigued/Drowsy                       0.087089
# Following Too Closely                 0.046692
# Illness                               0.004557
# Lost Consciousness                    0.036351
# Other Electronic Device               0.004063
# Other Vehicular                       0.061987
# Outside Car Distraction               0.019499
# Oversized Vehicle                     0.012101
# Passenger Distraction                 0.009039
# Passing or Lane Usage Improper        0.021873
# Pavement Slippery                     0.020000
# Physical Disability                   0.016831
# ...

# %%
taxi_list.to_csv('taxi.csv')

# %%
df1 = Collision_data[Collision_data.LONGITUDE <= -73.96]

# %%
df1 = df1[df1.LONGITUDE >= -74.013]

# %%
df1.head()
# Out:
#           DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 2   10/22/2017  0:00  MANHATTAN    10011  40.739136 -73.999260
# 3   10/22/2017  0:00  MANHATTAN    10025  40.794235 -73.962814
# 15  10/22/2017  0:30   BROOKLYN    11201  40.701440 -73.984770
# 19  10/22/2017  0:50  MANHATTAN    10002  40.719750 -73.992165
# 22  10/22/2017  0:58  MANHATTAN    10019  40.761093 -73.983270
#
#                    LOCATION                    ON STREET NAME  \
# 2    (40.739136, -73.99926)                               NaN
# 3   (40.794235, -73.962814)  CENTRAL PARK WEST
# 15    (40.70144, -73.98477)  YORK STREET
# 19   (40.71975, -73.992165)  DELANCEY STREET
# 22   (40.761093, -73.98327)  WEST 50 STREET
#
#    CROSS STREET NAME                           OFF STREET NAME   ...    \
# 2                NaN  77        7 AVENUE                         ...
# 3    WEST 100 STREET                                       NaN   ...
# ...

# %%
df1 = df1[df1.LATITUDE >= 40.72]

# %%
df1 = df1[df1.LATITUDE <= 40.81]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135756 entries, 2 to 1139129
# Data columns (total 31 columns):
# DATE                             135756 non-null object
# TIME                             135756 non-null object
# BOROUGH                          127818 non-null object
# ZIP CODE                         127818 non-null object
# LATITUDE                         135756 non-null float64
# LONGITUDE                        135756 non-null float64
# LOCATION                         135756 non-null object
# ON STREET NAME                   124979 non-null object
# CROSS STREET NAME                120517 non-null object
# OFF STREET NAME                  17031 non-null object
# NUMBER OF PERSONS INJURED        135756 non-null int64
# NUMBER OF PERSONS KILLED         135756 non-null int64
# NUMBER OF PEDESTRIANS INJURED    135756 non-null int64
# NUMBER OF PEDESTRIANS KILLED     135756 non-null int64
# NUMBER OF CYCLIST INJURED        135756 non-null int64
# ...

# %%
23271/135756
# Out:
# 0.171

# %%
Collision_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1139133 entries, 0 to 1139132
# Data columns (total 31 columns):
# DATE                             1139133 non-null object
# TIME                             1139133 non-null object
# BOROUGH                          821108 non-null object
# ZIP CODE                         821029 non-null object
# LATITUDE                         928495 non-null float64
# LONGITUDE                        928495 non-null float64
# LOCATION                         928495 non-null object
# ON STREET NAME                   923773 non-null object
# CROSS STREET NAME                875872 non-null object
# OFF STREET NAME                  172400 non-null object
# NUMBER OF PERSONS INJURED        1139133 non-null int64
# NUMBER OF PERSONS KILLED         1139133 non-null int64
# NUMBER OF PEDESTRIANS INJURED    1139133 non-null int64
# NUMBER OF PEDESTRIANS KILLED     1139133 non-null int64
# NUMBER OF CYCLIST INJURED        1139133 non-null int64
# ...

# %%
df1[df1['VEHICLE TYPE CODE 1']== 'TAXI'].count()
# Out:
# DATE                             23271
# TIME                             23271
# BOROUGH                          22133
# ZIP CODE                         22133
# LATITUDE                         23271
# LONGITUDE                        23271
# LOCATION                         23271
# ON STREET NAME                   21579
# CROSS STREET NAME                20717
# OFF STREET NAME                   1491
# NUMBER OF PERSONS INJURED        23271
# NUMBER OF PERSONS KILLED         23271
# NUMBER OF PEDESTRIANS INJURED    23271
# NUMBER OF PEDESTRIANS KILLED     23271
# NUMBER OF CYCLIST INJURED        23271
# NUMBER OF CYCLIST KILLED         23271
# NUMBER OF MOTORIST INJURED       23271
# NUMBER OF MOTORIST KILLED        23271
# CONTRIBUTING FACTOR VEHICLE 1    23154
# CONTRIBUTING FACTOR VEHICLE 2    20315
# CONTRIBUTING FACTOR VEHICLE 3      658
# CONTRIBUTING FACTOR VEHICLE 4       85
# CONTRIBUTING FACTOR VEHICLE 5       14
# UNIQUE KEY                       23271
# ...

# %%
Collision_data[Collision_data['VEHICLE TYPE CODE 1']== 'TAXI'].count()
# Out:
# DATE                             43923
# TIME                             43923
# BOROUGH                          35954
# ZIP CODE                         35954
# LATITUDE                         39211
# LONGITUDE                        39211
# LOCATION                         39211
# ON STREET NAME                   38122
# CROSS STREET NAME                35559
# OFF STREET NAME                   2934
# NUMBER OF PERSONS INJURED        43923
# NUMBER OF PERSONS KILLED         43923
# NUMBER OF PEDESTRIANS INJURED    43923
# NUMBER OF PEDESTRIANS KILLED     43923
# NUMBER OF CYCLIST INJURED        43923
# NUMBER OF CYCLIST KILLED         43923
# NUMBER OF MOTORIST INJURED       43923
# NUMBER OF MOTORIST KILLED        43923
# CONTRIBUTING FACTOR VEHICLE 1    43729
# CONTRIBUTING FACTOR VEHICLE 2    38189
# CONTRIBUTING FACTOR VEHICLE 3     1800
# CONTRIBUTING FACTOR VEHICLE 4      305
# CONTRIBUTING FACTOR VEHICLE 5       65
# UNIQUE KEY                       43923
# ...

# %%
43923/1139133
# Out:
# 0.039
